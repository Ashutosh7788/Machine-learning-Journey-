# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashutosh7788/Machine-learning-Journey-/blob/main/ML_1st_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Steps

# 0. Preprocess + EDA + Feature Selection
# 1. Extract input and output cols
# 2. Scale the values
# 3. Train test split
# 4. Train the model
# 5. Evaluate the model/model selection
# 6. Deploy the model

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df.shape
# Out:
# (100, 4)

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
x.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 27   6.0  124.0
# 94   4.7   52.0
# 14   6.1  103.0
# 56   6.1   65.0
# 18   4.0  100.0
# ..   ...    ...
# 51   4.8  141.0
# 49   5.4  135.0
# 17   3.3  183.0
# 12   5.4  139.0
# 50   3.5  233.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 27    1
# 94    0
# 14    0
# 56    0
# 18    0
#      ..
# 51    0
# 49    0
# 17    0
# 12    0
# 50    0
# Name: placement, Length: 90, dtype: int64

# %%
x_test
# Out:
#     cgpa     iq
# 79   6.5   90.0
# 43   6.8  141.0
# 64   7.0   64.0
# 35   6.8   90.0
# 1    5.9  106.0
# 52   7.0  175.0
# 87   5.7  132.0
# 84   5.7  169.0
# 67   5.0  118.0
# 88   4.4  149.0

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 0.0162118 ,  0.00992836],
#        [-1.0995418 , -1.77717654],
#        [ 0.102039  , -0.51131057],
#        [ 0.102039  , -1.45450483],
#        [-1.7003322 , -0.58577327],
#        [ 0.78865661,  0.35742098],
#        [-0.2412698 ,  0.40706278],
#        [ 0.96031101,  0.6800927 ],
#        [ 1.13196541, -1.82681835],
#        [ 0.18786621, -0.26310156],
#        [-0.9278874 ,  1.79703327],
#        [ 0.44534781, -2.14949007],
#        [ 0.61700221,  0.7545554 ],
#        [ 1.13196541,  0.33260008],
#        [-1.4428506 ,  1.89631687],
#        [ 0.102039  ,  0.80419721],
#        [ 0.0162118 , -1.95092285],
#        [-1.0137146 ,  0.97794352],
#        [-0.6704058 ,  0.20849557],
#        [-0.6704058 ,  2.49201851],
#        [ 0.61700221,  1.44954065],
#        [ 0.27369341,  0.10921197],
#        [ 1.30361981,  0.85383901],
#        [ 0.35952061, -0.18863885],
#        [ 1.73275581, -1.10701221],
#        [-1.0137146 ,  1.12686893],
#        [ 0.70282941, -0.28792246],
# ...

# %%
x_test = scaler.transform(x_test)
x_test
# Out:
# array([[ 0.44534781, -0.83398229],
#        [ 0.70282941,  0.43188369],
#        [ 0.87448381, -1.47932573],
#        [ 0.70282941, -0.83398229],
#        [-0.0696154 , -0.43684787],
#        [ 0.87448381,  1.27579434],
#        [-0.2412698 ,  0.20849557],
#        [-0.2412698 ,  1.12686893],
#        [-0.8420602 , -0.13899705],
#        [-1.3570234 ,  0.6304509 ]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
#model training
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(x_test)

# %%
y_test
# Out:
# 79    1
# 43    1
# 64    1
# 35    1
# 1     0
# 52    1
# 87    1
# 84    0
# 67    0
# 88    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train, y_train.values , clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
